# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
from LATAPMon import *

# %%
sL = loadSourceList()

# %%
data = loadSourceData(sL,'./ap_lcs/',True, False)

# %%
fig = figure(figsize=(14,6))
ax1 = fig.add_subplot(111)
xtickNames = plt.setp(ax1, xticklabels=[source['name'] for source in data[:50]])
plt.setp(xtickNames, rotation=45, fontsize=8)

bp = boxplot([source['data']['deviations'] for source in data[:50]])
show()

# %%
fig = figure(figsize=(14,6))
ax1 = fig.add_subplot(111)

bp = boxplot(calcSourceStatistics(openCurve(getCurve("2FGLJ1059.3-1132")))['deviations'])
show()

# %%
patches = hist(hstack([source['data']['deviations'] for source in data]), bins=100)

# %%
flares = findFlares(data,56329,28,4,True)
# Out:
# The largest negative deviation is -3.08361776486 cm^-2 s^-1.
# The largest positive deviation is 10.0340640851 cm^-2 s^-1.
# The mean deviation is 0.0374049234813 cm^-2 s^-1.
# The standard deviation of the deviations is 0.790309442091 cm^-2 s^-1.
# Looking for flares greater than 3.16123776836 cm^-2 s^-1 starting on MJD 56301.

# %%
printFlares(flares,sL,False,'flares.html',56322,28,True)
# Out:
# Loaded 2FGL from FSSC.
# Stored the 2FGL fits file as /var/folders/wf/fd0h95195b10ycgh_g0vdn8m8ftw9h/T/tmpmaiZxu.fit.
# 2FGLJ1428.0-4206
# 	Association: PKS B1424-418
# 	Location: 217.01204,-42.103615
# 	Flare Level(s): [ 5.42096886]
# 	Flare Date(s): [ 56315.31723023]
# 	Light Curve: http://fermi.gsfc.nasa.gov/ssc/data/access/lat/2yr_catalog/ap_lcs/lightcurve_2FGLJ1428.0-4206.png
#
# 2FGLJ2345.0-1553
# 	Association: PMN J2345-1555
# 	Location: 356.26898,-15.887058
# 	Flare Level(s): [ 3.87591475]
# 	Flare Date(s): [ 56315.31723023]
# 	Light Curve: http://fermi.gsfc.nasa.gov/ssc/data/access/lat/2yr_catalog/ap_lcs/lightcurve_2FGLJ2345.0-1553.png
#
# 2FGLJ2012.1+4630
# 	Association: 7C 2010+4619
# 	Location: 303.03467,46.507965
# 	Flare Level(s): [ 4.23168634]
# 	Flare Date(s): [ 56315.31723023]
# 	Light Curve: http://fermi.gsfc.nasa.gov/ssc/data/access/lat/2yr_catalog/ap_lcs/lightcurve_2FGLJ2012.1p4630.png
#
# 2FGLJ1517.7-2421
# 	Association: AP Librae
# 	Location: 229.43498,-24.360027
# 	Flare Level(s): [ 3.81410841]
# 	Flare Date(s): [ 56315.31723023]
# 	Light Curve: http://fermi.gsfc.nasa.gov/ssc/data/access/lat/2yr_catalog/ap_lcs/lightcurve_2FGLJ1517.7-2421.png
#
# 2FGLJ1059.3-1132
# 	Association: PKS B1056-113
# 	Location: 164.83272,-11.54085
# 	Flare Level(s): [ 3.49010232]
# 	Flare Date(s): [ 56315.31723023]
# 	Light Curve: http://fermi.gsfc.nasa.gov/ssc/data/access/lat/2yr_catalog/ap_lcs/lightcurve_2FGLJ1059.3-1132.png
#
# 2FGLJ2151.5-3021
# 	Association: PKS 2149-306
# 	Location: 327.89191,-30.359875
# 	Flare Level(s): [ 6.0850827]
# 	Flare Date(s): [ 56315.31723023]
# 	Light Curve: http://fermi.gsfc.nasa.gov/ssc/data/access/lat/2yr_catalog/ap_lcs/lightcurve_2FGLJ2151.5-3021.png
#
# 2FGLJ2347.9-1629
# 	Association: PKS 2345-16
# 	Location: 356.98392,-16.487057
# 	Flare Level(s): [ 3.31391242]
# 	Flare Date(s): [ 56315.31723023]
# 	Light Curve: http://fermi.gsfc.nasa.gov/ssc/data/access/lat/2yr_catalog/ap_lcs/lightcurve_2FGLJ2347.9-1629.png
#
# 2FGLJ1048.3+7144
# 	Association: S5 1044+71
# 	Location: 162.08701,71.738472
# 	Flare Level(s): [ 3.8040893]
# 	Flare Date(s): [ 56315.31723023]
# 	Light Curve: http://fermi.gsfc.nasa.gov/ssc/data/access/lat/2yr_catalog/ap_lcs/lightcurve_2FGLJ1048.3p7144.png
#
# 2FGLJ0643.2+0858
# 	Association: PMN J0643+0857
# 	Location: 100.81477,8.9816656
# 	Flare Level(s): [ 4.03717213]
# 	Flare Date(s): [ 56315.31723023]
# 	Light Curve: http://fermi.gsfc.nasa.gov/ssc/data/access/lat/2yr_catalog/ap_lcs/lightcurve_2FGLJ0643.2p0858.png
